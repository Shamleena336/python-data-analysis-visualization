# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\DELL\Downloads\IBM HR Data new.csv~\IBM HR Data new.csv",low_memory=False)

# %%
df
# Out:
#         Age              Attrition     BusinessTravel  DailyRate  \
# 0      41.0  Voluntary Resignation      Travel_Rarely     1102.0
# 1      41.0  Voluntary Resignation      Travel_Rarely     1102.0
# 2      41.0  Voluntary Resignation      Travel_Rarely     1102.0
# 3      41.0  Voluntary Resignation      Travel_Rarely     1102.0
# 4      41.0  Voluntary Resignation      Travel_Rarely     1102.0
# ...     ...                    ...                ...        ...
# 23431  60.0       Current employee      Travel_Rarely      370.0
# 23432  60.0       Current employee      Travel_Rarely      370.0
# 23433   NaN  Voluntary Resignation  Travel_Frequently     1009.0
# 23434   NaN       Current employee      Travel_Rarely     1354.0
# 23435   NaN       Current employee         Non-Travel     1142.0
#
#                    Department DistanceFromHome  Education EducationField  \
# 0                       Sales                1        2.0  Life Sciences
# ...

# %%
#load the dataset and display first 10 rows

# %%
df.head(10)
# Out:
#     Age              Attrition BusinessTravel  DailyRate Department  \
# 0  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
# 1  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
# 2  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
# 3  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
# 4  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
# 5  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
# 6  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
# 7  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
# 8  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
# 9  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
#
#   DistanceFromHome  Education EducationField EmployeeCount EmployeeNumber  \
# 0                1        2.0  Life Sciences             1              1
# ...

# %%
#find the number of rows and columns in the data set

# %%
df.shape
# Out:
# (23436, 37)

# %%
# check the missing values in each column

# %%
df.isnull().sum()
# Out:
# Age                          3
# Attrition                   13
# BusinessTravel               8
# DailyRate                   12
# Department                  11
# DistanceFromHome             9
# Education                   12
# EducationField               9
# EmployeeCount                5
# EmployeeNumber               1
# Application ID               3
# EnvironmentSatisfaction      9
# Gender                      10
# HourlyRate                   9
# JobInvolvement               9
# JobLevel                     7
# JobRole                      9
# JobSatisfaction              9
# MaritalStatus               11
# MonthlyIncome               13
# MonthlyRate                 11
# NumCompaniesWorked           9
# Over18                      10
# OverTime                    12
# PercentSalaryHike           14
# PerformanceRating           10
# RelationshipSatisfaction     8
# StandardHours               10
# StockOptionLevel             9
# TotalWorkingYears            8
# ...

# %%
#display the unique job roles present in the dataset

# %%
role=df["JobRole"].unique()

# %%
role
# Out:
# array(['Sales Executive', 'Manager', 'Research Director',
#        'Sales Representative', 'Laboratory Technician',
#        'Research Scientist', 'Manufacturing Director',
#        'Healthcare Representative', 'Human Resources', nan, '5', '4'],
#       dtype=object)

# %%
#find the avarage age of employees

# %%
average=df["Age"].mean()

# %%
average
# Out:
# 36.93667050740409

# %%
#how many employees belong to each department

# %%
df.groupby('Department')['EmployeeCount'].count()
# Out:
# Department
# 1296                          1
# Human Resources            1019
# Research & Development    15282
# Sales                      7118
# Name: EmployeeCount, dtype: int64

# %%
#find the duplicates and remove duplicates

# %%
df.duplicated().sum()
# Out:
# 14

# %%
df.drop_duplicates()
# Out:
#         Age              Attrition     BusinessTravel  DailyRate  \
# 0      41.0  Voluntary Resignation      Travel_Rarely     1102.0
# 1      41.0  Voluntary Resignation      Travel_Rarely     1102.0
# 2      41.0  Voluntary Resignation      Travel_Rarely     1102.0
# 3      41.0  Voluntary Resignation      Travel_Rarely     1102.0
# 4      41.0  Voluntary Resignation      Travel_Rarely     1102.0
# ...     ...                    ...                ...        ...
# 23431  60.0       Current employee      Travel_Rarely      370.0
# 23432  60.0       Current employee      Travel_Rarely      370.0
# 23433   NaN  Voluntary Resignation  Travel_Frequently     1009.0
# 23434   NaN       Current employee      Travel_Rarely     1354.0
# 23435   NaN       Current employee         Non-Travel     1142.0
#
#                    Department DistanceFromHome  Education EducationField  \
# 0                       Sales                1        2.0  Life Sciences
# ...

# %%
#get the minimum maximum and avarage monthlyrate of employees

# %%
minimum=df["MonthlyRate"].min()

# %%
minimum
# Out:
# 2094.0

# %%
maximum=df["MonthlyRate"].max()

# %%
maximum
# Out:
# 26999.0

# %%
avarage=df["MonthlyRate"].mean()

# %%
avarage
# Out:
# 14304.343820704376

# %%
#filter the employees whose attrition is yes

# %%
yes=df[df["Attrition"]=="yes"]

# %%
yes
# Out:
# Empty DataFrame
# Columns: [Age, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, EmployeeCount, EmployeeNumber, Application ID, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, Over18, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager, Employee Source]
# Index: []
#
# [0 rows x 37 columns]

# %%
#find the top 5 employees with highest income

# %%
df["MonthlyIncome"]=pd.to_numeric(df["MonthlyIncome"],errors="coerce")

# %%
larage=df["MonthlyIncome"].nlargest(5)

# %%
large
# Out:
# 5941    26999.0
# 5942    26999.0
# 5945    26999.0
# 5946    26999.0
# 6268    26999.0
# Name: MonthlyRate, dtype: float64

# %%
#group employees by jobrole and find the average monthly income

# %%
avg=df.groupby("JobRole")["MonthlyRate"].mean()

# %%
avg
# Out:
# JobRole
# 4                            16659.000000
# 5                            19232.000000
# Healthcare Representative    14379.971008
# Human Resources              13498.053254
# Laboratory Technician        13994.206971
# Manager                      15148.352500
# Manufacturing Director       14346.630892
# Research Director            15088.106615
# Research Scientist           14003.662133
# Sales Executive              14561.503132
# Sales Representative         13865.601072
# Name: MonthlyRate, dtype: float64

# %%
#sort the employees based on years at ompany in descending order

# %%
sort=df.sort_values(by="YearsAtCompany",ascending=False)

# %%
sort
# Out:
#         Age              Attrition BusinessTravel  DailyRate  \
# 16261  58.0  Voluntary Resignation  Travel_Rarely      147.0
# 176    41.0       Current employee  Travel_Rarely     1411.0
# 16255  58.0  Voluntary Resignation  Travel_Rarely      147.0
# 16256  58.0  Voluntary Resignation  Travel_Rarely      147.0
# 169    41.0       Current employee  Travel_Rarely     1411.0
# ...     ...                    ...            ...        ...
# 14011  19.0  Voluntary Resignation  Travel_Rarely      419.0
# 19137  38.0       Current employee  Travel_Rarely     1333.0
# 19899  40.0       Current employee     Non-Travel      458.0
# 20532  40.0       Current employee  Travel_Rarely      107.0
# 20684  52.0       Current employee  Travel_Rarely     1053.0
#
#                    Department DistanceFromHome  Education    EducationField  \
# 16261  Research & Development               23        4.0           Medical
# 176    Research & Development               19        2.0           Medical
# ...

# %%
#create anew column that shows the total working years multiplied by monthly income

# %%
df["LifetimeEarnigs"]=df["TotalWorkingYears"]*df["MonthlyIncome"]

# %%
df
# Out:
#         Age              Attrition     BusinessTravel  DailyRate  \
# 0      41.0  Voluntary Resignation      Travel_Rarely     1102.0
# 1      41.0  Voluntary Resignation      Travel_Rarely     1102.0
# 2      41.0  Voluntary Resignation      Travel_Rarely     1102.0
# 3      41.0  Voluntary Resignation      Travel_Rarely     1102.0
# 4      41.0  Voluntary Resignation      Travel_Rarely     1102.0
# ...     ...                    ...                ...        ...
# 23431  60.0       Current employee      Travel_Rarely      370.0
# 23432  60.0       Current employee      Travel_Rarely      370.0
# 23433   NaN  Voluntary Resignation  Travel_Frequently     1009.0
# 23434   NaN       Current employee      Travel_Rarely     1354.0
# 23435   NaN       Current employee         Non-Travel     1142.0
#
#                    Department DistanceFromHome  Education EducationField  \
# 0                       Sales                1        2.0  Life Sciences
# ...

# %%
df.head()
# Out:
#     Age              Attrition BusinessTravel  DailyRate Department  \
# 0  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
# 1  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
# 2  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
# 3  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
# 4  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
#
#   DistanceFromHome  Education EducationField EmployeeCount EmployeeNumber  \
# 0                1        2.0  Life Sciences             1              1
# 1                1        2.0  Life Sciences             1              1
# 2                1        2.0  Life Sciences             1              7
# 3                1        2.0  Life Sciences             1              8
# 4                1        2.0  Life Sciences             1              9
#
#    ... StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  \
# ...

# %%
#find the employees who have worked more than 10 years and have income above 10000

# %%
high=df[(df["YearsAtCompany"]>10)&(df["MonthlyIncome"]>1000)]

# %%
high
# Out:
#         Age              Attrition BusinessTravel  DailyRate  \
# 6      41.0  Voluntary Resignation  Travel_Rarely     1102.0
# 21     41.0  Voluntary Resignation  Travel_Rarely     1360.0
# 22     41.0  Voluntary Resignation  Travel_Rarely     1360.0
# 23     41.0  Voluntary Resignation  Travel_Rarely     1360.0
# 24     41.0  Voluntary Resignation  Travel_Rarely     1360.0
# ...     ...                    ...            ...        ...
# 23415  60.0       Current employee  Travel_Rarely      696.0
# 23416  60.0       Current employee  Travel_Rarely      696.0
# 23427  60.0       Current employee  Travel_Rarely      370.0
# 23431  60.0       Current employee  Travel_Rarely      370.0
# 23434   NaN       Current employee  Travel_Rarely     1354.0
#
#                    Department DistanceFromHome  Education    EducationField  \
# 6                       Sales                1        2.0     Life Sciences
# 21     Research & Development               12        3.0  Technical Degree
# ...

# %%
import matplotlib.pyplot as plt

# %%
#plot a histogram of employees ages

# %%
plt.hist("Age",bins=5,color="b")
# Out:
# (array([0., 0., 1., 0., 0.]),
#  array([-0.5, -0.3, -0.1,  0.1,  0.3,  0.5]),
#  <BarContainer object of 5 artists>)

# %%
#create a bar chart showing the number of employees per department

# %%
df["Department"].value_counts().plot(kind="bar",color="red")
plt.xlabel("Department")
plt.ylabel("Department")
plt.title("Employees per Department")
plt.show()

# %%
#plot a pie chart for gender

# %%
df['Gender'].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
#plot a scatter plot of yeras at company vs monthaly income

# %%
a=df['YearsAtCompany']

# %%
a
# Out:
# 0         6.0
# 1         6.0
# 2         6.0
# 3         6.0
# 4         6.0
#          ...
# 23431    20.0
# 23432     1.0
# 23433     2.0
# 23434    11.0
# 23435     2.0
# Name: YearsAtCompany, Length: 23436, dtype: float64

# %%
b=df["MonthlyIncome"]=pd.to_numeric(df["MonthlyIncome"],errors="coerce")

# %%
b
# Out:
# 0         5993.0
# 1         5993.0
# 2         5993.0
# 3         5993.0
# 4         5993.0
#           ...
# 23431    10883.0
# 23432    10883.0
# 23433     5301.0
# 23434    11631.0
# 23435     4069.0
# Name: MonthlyIncome, Length: 23436, dtype: float64

# %%
plt.scatter(a,b)
plt.xlabel('YearsAtCompany')
plt.ylabel('MonthlyIncome')
plt.show()

# %%
#plot a histogram age column

# %%
plt.hist(df['Age'],bins=20,color='blue')
# Out:
# (array([ 445.,  470.,  639., 1028., 1526., 2027., 2069., 2157., 2333.,
#         1751., 2202., 1249., 1178.,  903.,  689.,  783.,  597.,  636.,
#          286.,  465.]),
#  array([18. , 20.1, 22.2, 24.3, 26.4, 28.5, 30.6, 32.7, 34.8, 36.9, 39. ,
#         41.1, 43.2, 45.3, 47.4, 49.5, 51.6, 53.7, 55.8, 57.9, 60. ]),
#  <BarContainer object of 20 artists>)

# %%
#plot a line graph of years at company against monthly income

# %%
data=df.groupby("YearsAtCompany")["MonthlyIncome"].mean().plot(kind="line")
plt.title("YearsAtCompany vs Average MonthlyIncome")
plt.xlabel("YearsAtCompany")
plt.ylabel("MonthlyIncome")
# Out:
# Text(0, 0.5, 'MonthlyIncome')

# %%
#Show the average MonthlyIncome for each JobRole using a bar chart.

# %%
a=df["MonthlyIncome"]=pd.to_numeric(df["MonthlyIncome"],errors="coerce")

# %%
a
# Out:
# 0         5993.0
# 1         5993.0
# 2         5993.0
# 3         5993.0
# 4         5993.0
#           ...
# 23431    10883.0
# 23432    10883.0
# 23433     5301.0
# 23434    11631.0
# 23435     4069.0
# Name: MonthlyIncome, Length: 23436, dtype: float64

# %%
data=df.groupby("JobRole")["MonthlyIncome"].mean().plot(kind="bar")
plt.title("Average Monthly Income by JobRole")
plt.xlabel("JobRole")
plt.ylabel("MonthlyIncome")
# Out:
# Text(0, 0.5, 'MonthlyIncome')

# %%
#Plot the count of employees in each JobRole using a horizontal bar chart.

# %%
jobrole_counts = df["JobRole"].value_counts()
jobrole_counts.plot(kind="barh", color="skyblue")
plt.title("Employee Count by JobRole")
plt.xlabel("EmployeeCount")
plt.ylabel("JobRole")
# Out:
# Text(0, 0.5, 'JobRole')

# %%
#Compare YearsAtCompany and YearsInCurrentRole with a multi-line plot.

# %%
df.groupby("YearsAtCompany")["YearsInCurrentRole"].mean().plot(linestyle="-", color="blue")
plt.title("Comparison of YearsAtCompany and YearsInCurrentRole")
plt.xlabel("YearsAtCompany")
plt.ylabel("YearsAtCompany")
# Out:
# Text(0, 0.5, 'YearsAtCompany')

# %%
#compare the avarage monthly income of males vs females using bar chart

# %%
df.groupby("Gender")["MonthlyIncome"].mean().plot(kind="bar")
plt.title("avarage monthly income")
plt.xlabel("Gender")
plt.ylabel("MonthlyIncome")
# Out:
# Text(0, 0.5, 'MonthlyIncome')

# %%
import seaborn as sns

# %%
#create a counterplot of attrition

# %%
sns.countplot(data=df['Attrition'])
# Out:
# <Axes: xlabel='count', ylabel='Attrition'>

# %%
#create countplot of employees by department

# %%
sns.countplot(data=df, x="EmployeeCount", hue="Department")
# Out:
# <Axes: xlabel='EmployeeCount', ylabel='count'>

# %%
#create a boxplot of monthly income by jobrole

# %%
sns.boxplot(data=df,x="MonthlyIncome",hue="JobRole")
# Out:
# <Axes: xlabel='MonthlyIncome'>

# %%
#create a violoinplot of age by attrition

# %%
sns.violinplot(data=df,x="Age",y="Attrition")
# Out:
# <Axes: xlabel='Age', ylabel='Attrition'>

# %%
#create a pairplot for age,monthlyincome and years at company

# %%
a=["Age","MonthlyIncome","YearsAtCompany"]

# %%
sns.pairplot(df[a])

# %%
#create a stripplot of monthly income grouped by department

# %%
a=df["MonthlyIncome"]=pd.to_numeric(df["MonthlyIncome"],errors="coerce")
sns.stripplot(df.groupby("Department")["MonthlyIncome"].mean())
# Out:
# <Axes: ylabel='MonthlyIncome'>

# %%
#create a stripplot of yearsatcompany vs monthlyincome

# %%
sns.stripplot(data=df,x="YearsAtCompany",y="MonthlyIncome")
# Out:
# <Axes: xlabel='YearsAtCompany', ylabel='MonthlyIncome'>

# %%
#create a kde plot for the ditribution of monthlyincome

# %%
sns.kdeplot(df["MonthlyIncome"])
# Out:
# <Axes: xlabel='MonthlyIncome', ylabel='Density'>

# %%
#create a swarmplot of jobrole vs monthlyincome

# %%
sns.swarmplot(data=df,x="JobRole",y="MonthlyIncome")
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 96.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 91.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 89.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 93.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
import numpy as np

# %%
#create a numpy array from the age column and calculate mean median and sd

# %%
df["Age"]
# Out:
# 0        41.0
# 1        41.0
# 2        41.0
# 3        41.0
# 4        41.0
#          ...
# 23431    60.0
# 23432    60.0
# 23433     NaN
# 23434     NaN
# 23435     NaN
# Name: Age, Length: 23436, dtype: float64

# %%
mean=df["Age"].mean()

# %%
mean
# Out:
# 36.93667050740409

# %%
median=df["Age"].median()

# %%
median
# Out:
# 36.0

# %%
sd=df["Age"].std()

# %%
sd
# Out:
# 9.137431828640084

# %%
#use numpy to find the vmax min value ofin the monthlyincome column

# %%
df["MonthlyIncome"]=pd.to_numeric(df["MonthlyIncome"],errors="coerce")

# %%
max_income = df["MonthlyIncome"].max()
print("Maximum Monthly Income:", max_income)
# Out:
# Maximum Monthly Income: 19999.0

# %%
df["MonthlyIncome"]
# Out:
# 0         5993.0
# 1         5993.0
# 2         5993.0
# 3         5993.0
# 4         5993.0
#           ...
# 23431    10883.0
# 23432    10883.0
# 23433     5301.0
# 23434    11631.0
# 23435     4069.0
# Name: MonthlyIncome, Length: 23436, dtype: float64

# %%
minimum=df["MonthlyIncome"].min()

# %%
minimum
# Out:
# 1009.0

# %%
# normalize the age column using numpy

# %%
age=df["Age"]

# %%
age
# Out:
# 0        41.0
# 1        41.0
# 2        41.0
# 3        41.0
# 4        41.0
#          ...
# 23431    60.0
# 23432    60.0
# 23433     NaN
# 23434     NaN
# 23435     NaN
# Name: Age, Length: 23436, dtype: float64

# %%
age_normalize=(age-np.min(age))/(np.max(age)-np.min(age))

# %%
age_normalize
# Out:
# 0        0.547619
# 1        0.547619
# 2        0.547619
# 3        0.547619
# 4        0.547619
#            ...
# 23431    1.000000
# 23432    1.000000
# 23433         NaN
# 23434         NaN
# 23435         NaN
# Name: Age, Length: 23436, dtype: float64

# %%
#create a boolean numpy mask for employees with more than 5 years at the company

# %%
mask=df['YearsAtCompany'].values>5

# %%
mask
# Out:
# array([ True,  True,  True, ..., False,  True, False])

# %%
#use numpy to find the max min value ofin the MonthlyRate  column

# %%
df['MonthlyRate']
# Out:
# 0        19479.0
# 1        19479.0
# 2        19479.0
# 3        19479.0
# 4        19479.0
#           ...
# 23431    20467.0
# 23432    20467.0
# 23433     2939.0
# 23434     5615.0
# 23435     8841.0
# Name: MonthlyRate, Length: 23436, dtype: float64

# %%
maximum=df["MonthlyRate"].max()

# %%
maximum
# Out:
# 26999.0

# %%
minimum=df["MonthlyRate"].max()

# %%
minimum
# Out:
# 26999.0
